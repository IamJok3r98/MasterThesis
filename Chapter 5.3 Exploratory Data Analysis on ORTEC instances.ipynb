# %% [markdown]
# ## Import general packages

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ## Define locations

# %%
# Change this to the path of your repo.
loc_main = 'C:\\Users\\johanr\\OneDrive - Ortec B.V\\Data Analysis for Strengths and Weaknesses\\Sustainable_code_structure'

# Define paths inside of our repo
loc_input_data = os.path.join(loc_main, 'data', 'input')
loc_intermediate_data = os.path.join(loc_main, 'data', 'intermediate')
loc_output_data = os.path.join(loc_main, 'data', 'output')
loc_utils = os.path.join(loc_main, 'code')

# %% [markdown]
# ## Import own functionalities

# %%
sys.path.insert(1, loc_utils)
from data_utils import plot_histogram,plot_histogram_start_at_0

# %% [markdown]
# ## Import required data

# %%
filepath = loc_intermediate_data + "\\Ortecs customer feature dataframe.csv"
dataframe = pd.read_csv(filepath)

# %% [markdown]
# ## Figure 5.7 : Distribution of the number of customers across 97 instances

# %%
plot_histogram(dataframe,'Number of customers','Ortecs Client')

# %% [markdown]
# ## Figure 5.8 Distribution of the number of vehicles across 97 instances

# %%
plot_histogram(dataframe,'Number of vehicles','Ortecs Client')

# %% [markdown]
# ## Figure 5.9 Distribution of the number of clusters across 97 instances

# %%
plot_histogram(dataframe,'Number of clusters','Ortecs Client')

# %% [markdown]
# ## Figure 5.10 Distribution of the mean of distance matrix across 97 instances

# %%
plot_histogram(dataframe,'Mean Dist Matrix','Ortecs Client')

# %% [markdown]
# ## 5.11 Distribution of the standard deviation of distance matrix across 97 instances

# %%
plot_histogram(dataframe,'Std Dist Matrix','Ortecs Client')

# %% [markdown]
# ## 5.12 Distribution of the mean of the distances between depot and centroid across 97 instances

# %%
plot_histogram(dataframe,'Mean Distance Depot Centroid','Ortecs Client')

# %% [markdown]
# ## 5.13 Distribution of the mean of the duration of the time windows of the customers across 97 instances

# %%
plot_histogram_start_at_0(dataframe,'Customer Time Window Mean','Ortecs Client')

# %% [markdown]
# ## 5.14 Distribution of the standard deviation of the duration of the time windows of the customers across 97 instances

# %%
plot_histogram(dataframe,'Customer Time Window Std','Ortecs Client')

# %% [markdown]
# # 5.15 Distribution of the mean of the duration of the time window lengths of the vehicles across 97 instances

# %%
plot_histogram_start_at_0(dataframe,'Vehicles Time Window Mean','Ortecs Client')

# %% [markdown]
# ## 5.16 Distribution of the standard deviation of the duration of the time windows of the vehicles across 97 instances

# %%
plot_histogram(dataframe,'Vehicles Time Window Std','Ortecs Client')

# %% [markdown]
# ## 5.17 Distribution of the customer demand location across 97 instances

# %%
plot_histogram_start_at_0(dataframe,'Customer Demand Location','Ortecs Client',0,1)

# %% [markdown]
# ## 5.18 Distribution of the vehicle availability location across 97 instances

# %%
plot_histogram_start_at_0(dataframe,'Vehicle Availability','Ortecs Client',0,1)
