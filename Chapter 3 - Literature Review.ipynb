# %% [markdown]
# ## Import general packages

# %%
import pandas as pd
import os
import sys
import numpy as np

# %% [markdown]
# ## Define locations

# %%
# Change this to the path of your repo.
loc_main = 'C:\\Users\\johanr\\OneDrive - Ortec B.V\\Data Analysis for Strengths and Weaknesses\\Sustainable_code_structure'

# Define paths inside of our repo
loc_input_data = os.path.join(loc_main, 'data', 'input')
loc_intermediate_data = os.path.join(loc_main, 'data', 'intermediate')
loc_output_data = os.path.join(loc_main, 'data', 'output')
loc_utils = os.path.join(loc_main, 'code')

# %% [markdown]
# ## Import own functionalities

# %%
sys.path.insert(1, loc_utils)
from data_utils import plot_knee_from_array

# %% [markdown]
# ## Import required data

# %%
file4 = loc_intermediate_data + "\\4-distance plot example\\x_axis_data_DBSCAN_clust.npy"
file5 = loc_intermediate_data + "\\4-distance plot example\\y_axis_data_DBSCAN_clust.npy"

# %% [markdown]
# ## Figure 3.7 4-distance plot of an example instance with the elbow located in dotted line

# %%
plot_knee_from_array(np.load(file4),np.load(file5))
